# %% [markdown]
# # Adding photos to our data set -Extracting from Wikidata

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('2020_MUSIC.csv')

# %%
df
# Out:
#                  track_name           artist  \
# 0           Blinding Lights       The Weeknd
# 1              Dance Monkey      Tones And I
# 2                   The Box      Roddy Ricch
# 3                     Roses        SAINt JHN
# 4           Don't Start Now         Dua Lipa
# 5                  ROCKSTAR           DaBaby
# 6          Watermelon Sugar     Harry Styles
# 7                 death bed            Powfu
# 8                   Falling    Trevor Daniel
# 9         Someone You Loved    Lewis Capaldi
# 10                     Tusa          KAROL G
# 11                  ROXANNE   Arizona Zervas
# 12                  Circles      Post Malone
# 13          Blueberry Faygo        Lil Mosey
# 14               Intentions    Justin Bieber
# 15             Toosie Slide            Drake
# 16            Before You Go    Lewis Capaldi
# 17                   Say So         Doja Cat
# 18                 Memories         Maroon 5
# 19             Life Is Good           Future
# 20              Savage Love        Jawsh 685
# 21                Adore You     Harry Styles
# 22              Breaking Me            Topic
# 23                     Mood         24kGoldn
# 24      everything i wanted    Billie Eilish
# 25                 Señorita     Shawn Mendes
# 26                  bad guy    Billie Eilish
# 27                      WAP          Cardi B
# 28              Sunday Best         Surfaces
# 29                 Godzilla           Eminem
# 30                    Yummy    Justin Bieber
# 31           Break My Heart         Dua Lipa
# 32                 Dynamite              BTS
# 33               Supalonely            BENEE
# 34                      ily        Surf Mesa
# 35               Rain On Me        Lady Gaga
# 36      HIGHEST IN THE ROOM     Travis Scott
# 37                Sunflower      Post Malone
# 38                    Hawái           Maluma
# 39                  Ride It           Regard
# 40               goosebumps     Travis Scott
# 41                    RITMO  Black Eyed Peas
# 42               THE SCOTTS       THE SCOTTS
# 43                  Safaera        Bad Bunny
# 44                   lovely    Billie Eilish
# 45             Lucid Dreams       Juice WRLD
# 46             Stuck with U    Ariana Grande
# 47  If the World Was Ending          JP Saxe
# 48                 Physical         Dua Lipa
# 49               SICKO MODE     Travis Scott
#
#                                        album
# 0                                After Hours
# 1                               Dance Monkey
# 2      Please Excuse Me For Being Antisocial
# 3                                      Roses
# 4                           Future Nostalgia
# 5                           BLAME IT ON BABY
# 6                                  Fine Line
# 7                                  death bed
# 8                                   Nicotine
# 9    Divinely Uninspired To A Hellish Extent
# 10                                      Tusa
# 11                                   ROXANNE
# 12                      Hollywood's Bleeding
# 13                        Certified Hitmaker
# 14                                   Changes
# 15                      Dark Lane Demo Tapes
# 16   Divinely Uninspired To A Hellish Extent
# 17                                  Hot Pink
# 18                                  Memories
# 19                             High Off Life
# 20                               Savage Love
# 21                                 Fine Line
# 22                               Breaking Me
# 23                                      Mood
# 24                       everything i wanted
# 25                              Shawn Mendes
# 26  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 27                                       WAP
# 28                        Where the Light Is
# 29                   Music To Be Murdered By
# 30                                   Changes
# 31                          Future Nostalgia
# 32                                  Dynamite
# 33                                   Hey u x
# 34                                       ily
# 35                                Chromatica
# 36                       HIGHEST IN THE ROOM
# 37                      Hollywood's Bleeding
# 38                              PAPI JUANCHO
# 39                                   Ride It
# 40           Birds In The Trap Sing McKnight
# 41                               Translation
# 42                                THE SCOTTS
# 43                                  YHLQMDLG
# 44                                    lovely
# 45                   Goodbye & Good Riddance
# 46                              Stuck with U
# 47                   If the World Was Ending
# 48                          Future Nostalgia
# 49                                ASTROWORLD

# %% [markdown]
# Getting url of each artist

# %%
import requests
def get_url(artist):
    API_ENDPOINT = 'https://www.wikidata.org/w/api.php'
    query = str(artist)
    params = { 'action' : 'wbsearchentities','format':'json','language':'en','search':query}
    r = requests.get(API_ENDPOINT, params= params)
    url = r.json()['search'][0]['url']
    return url

# %% [markdown]
# Getting the image url from each artist

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request

final_links = []
for artist in df['artist']:
    url = get_url(artist)
    html = urllib.request.urlopen('https:'+url)
    soup = BeautifulSoup(html)
    images = soup.findAll('img')
    lista = []
    for image in images:
        link =image['src']
        lista.append(link)
        link_photo = lista[0]
    if 'upload' not in link_photo:
        final_links.append('NaN') #If there is no picture, do not append the link
    elif 'logo' in link_photo:
        final_links.append('NaN') #If the picture is a logo, do not append it
    else:
        final_links.append('http:'+link_photo)

# %% [markdown]
# Adding the picture to the data frame

# %%
df['image'] = final_links
image =df['image']

# %% [markdown]
# We tried to download the pictures as well, just in case we might need them

# %%
#downloading image
# import requests
# import shutil

# for person in df['artist']:
#     try:
#         link_photo = get_photo(person)
#         filename = link_photo.split("/")[-1]
#         resp = requests.get('https:'+link_photo, stream = True)
#         local_file = open(filename, 'wb')
#         resp.raw.decode_content = True
#         shutil.copyfileobj(resp.raw, local_file)
#         del resp
#         print(filename)
#     except:
#         print('Error downloading')

# %% [markdown]
#  We actually convert the empty cells in image to 'NaN'.

# %%
import numpy as np
df['image'].loc[df['image'] == 'NaN'] = np.nan
df
# Out:
#                  track_name           artist  \
# 0           Blinding Lights       The Weeknd
# 1              Dance Monkey      Tones And I
# 2                   The Box      Roddy Ricch
# 3                     Roses        SAINt JHN
# 4           Don't Start Now         Dua Lipa
# 5                  ROCKSTAR           DaBaby
# 6          Watermelon Sugar     Harry Styles
# 7                 death bed            Powfu
# 8                   Falling    Trevor Daniel
# 9         Someone You Loved    Lewis Capaldi
# 10                     Tusa          KAROL G
# 11                  ROXANNE   Arizona Zervas
# 12                  Circles      Post Malone
# 13          Blueberry Faygo        Lil Mosey
# 14               Intentions    Justin Bieber
# 15             Toosie Slide            Drake
# 16            Before You Go    Lewis Capaldi
# 17                   Say So         Doja Cat
# 18                 Memories         Maroon 5
# 19             Life Is Good           Future
# 20              Savage Love        Jawsh 685
# 21                Adore You     Harry Styles
# 22              Breaking Me            Topic
# 23                     Mood         24kGoldn
# 24      everything i wanted    Billie Eilish
# 25                 Señorita     Shawn Mendes
# 26                  bad guy    Billie Eilish
# 27                      WAP          Cardi B
# 28              Sunday Best         Surfaces
# 29                 Godzilla           Eminem
# 30                    Yummy    Justin Bieber
# 31           Break My Heart         Dua Lipa
# 32                 Dynamite              BTS
# 33               Supalonely            BENEE
# 34                      ily        Surf Mesa
# 35               Rain On Me        Lady Gaga
# 36      HIGHEST IN THE ROOM     Travis Scott
# 37                Sunflower      Post Malone
# 38                    Hawái           Maluma
# 39                  Ride It           Regard
# 40               goosebumps     Travis Scott
# 41                    RITMO  Black Eyed Peas
# 42               THE SCOTTS       THE SCOTTS
# 43                  Safaera        Bad Bunny
# 44                   lovely    Billie Eilish
# 45             Lucid Dreams       Juice WRLD
# 46             Stuck with U    Ariana Grande
# 47  If the World Was Ending          JP Saxe
# 48                 Physical         Dua Lipa
# 49               SICKO MODE     Travis Scott
#
#                                        album  \
# 0                                After Hours
# 1                               Dance Monkey
# 2      Please Excuse Me For Being Antisocial
# 3                                      Roses
# 4                           Future Nostalgia
# 5                           BLAME IT ON BABY
# 6                                  Fine Line
# 7                                  death bed
# 8                                   Nicotine
# 9    Divinely Uninspired To A Hellish Extent
# 10                                      Tusa
# 11                                   ROXANNE
# 12                      Hollywood's Bleeding
# 13                        Certified Hitmaker
# 14                                   Changes
# 15                      Dark Lane Demo Tapes
# 16   Divinely Uninspired To A Hellish Extent
# 17                                  Hot Pink
# 18                                  Memories
# 19                             High Off Life
# 20                               Savage Love
# 21                                 Fine Line
# 22                               Breaking Me
# 23                                      Mood
# 24                       everything i wanted
# 25                              Shawn Mendes
# 26  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 27                                       WAP
# 28                        Where the Light Is
# 29                   Music To Be Murdered By
# 30                                   Changes
# 31                          Future Nostalgia
# 32                                  Dynamite
# 33                                   Hey u x
# 34                                       ily
# 35                                Chromatica
# 36                       HIGHEST IN THE ROOM
# 37                      Hollywood's Bleeding
# 38                              PAPI JUANCHO
# 39                                   Ride It
# 40           Birds In The Trap Sing McKnight
# 41                               Translation
# 42                                THE SCOTTS
# 43                                  YHLQMDLG
# 44                                    lovely
# 45                   Goodbye & Good Riddance
# 46                              Stuck with U
# 47                   If the World Was Ending
# 48                          Future Nostalgia
# 49                                ASTROWORLD
#
#                                                 image
# 0   http://upload.wikimedia.org/wikipedia/commons/...
# 1   http://upload.wikimedia.org/wikipedia/commons/...
# 2   http://upload.wikimedia.org/wikipedia/commons/...
# 3   http://upload.wikimedia.org/wikipedia/commons/...
# 4                                                 NaN
# 5   http://upload.wikimedia.org/wikipedia/commons/...
# 6   http://upload.wikimedia.org/wikipedia/commons/...
# 7                                                 NaN
# 8                                                 NaN
# 9   http://upload.wikimedia.org/wikipedia/commons/...
# 10  http://upload.wikimedia.org/wikipedia/commons/...
# 11  http://upload.wikimedia.org/wikipedia/commons/...
# 12  http://upload.wikimedia.org/wikipedia/commons/...
# 13  http://upload.wikimedia.org/wikipedia/commons/...
# 14  http://upload.wikimedia.org/wikipedia/commons/...
# 15  http://upload.wikimedia.org/wikipedia/commons/...
# 16  http://upload.wikimedia.org/wikipedia/commons/...
# 17                                                NaN
# 18  http://upload.wikimedia.org/wikipedia/commons/...
# 19  http://upload.wikimedia.org/wikipedia/commons/...
# 20                                                NaN
# 21  http://upload.wikimedia.org/wikipedia/commons/...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  http://upload.wikimedia.org/wikipedia/commons/...
# 31                                                NaN
# 32  http://upload.wikimedia.org/wikipedia/commons/...
# 33  http://upload.wikimedia.org/wikipedia/commons/...
# 34  http://upload.wikimedia.org/wikipedia/commons/...
# 35  http://upload.wikimedia.org/wikipedia/commons/...
# 36  http://upload.wikimedia.org/wikipedia/commons/...
# 37  http://upload.wikimedia.org/wikipedia/commons/...
# 38  http://upload.wikimedia.org/wikipedia/commons/...
# 39                                                NaN
# 40  http://upload.wikimedia.org/wikipedia/commons/...
# 41  http://upload.wikimedia.org/wikipedia/commons/...
# 42                                                NaN
# 43  http://upload.wikimedia.org/wikipedia/commons/...
# 44                                                NaN
# 45  http://upload.wikimedia.org/wikipedia/commons/...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  http://upload.wikimedia.org/wikipedia/commons/...

# %% [markdown]
#  To get an idea of the pictures, we visualize the data set with the pictures included

# %%
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
df.to_html(escape=False, formatters=dict(image=path_to_image_html))
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>track_name</th>\n      <th>artist</th>\n      <th>album</th>\n      <th>image</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Blinding Lights</td>\n      <td>The Weeknd</td>\n      <td>After Hours</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/b/b8/FEQ_July_2018_The_Weeknd_%2844778856382%29_%28cropped%29.jpg/220px-FEQ_July_2018_The_Weeknd_%2844778856382%29_%28cropped%29.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Dance Monkey</td>\n      <td>Tones And I</td>\n      <td>Dance Monkey</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Tones_And_I_%2850118162967%29_%28cropped%29.jpg/220px-Tones_And_I_%2850118162967%29_%28cropped%29.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>The Box</td>\n      <td>Roddy Ricch</td>\n      <td>Please Excuse Me For Being Antisocial</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/5/5d/Roddy_Ricch_2019.png" width="60" ></td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Roses</td>\n      <td>SAINt JHN</td>\n      <td>Roses</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/d/d8/SAINt_JHN_2018.jpg/220px-SAINt_JHN_2018.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Don\'t Start Now</td>\n      <td>Dua Lipa</td>\n      <td>Future Nostalgia</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>ROCKSTAR</td>\n      <td>DaBaby</td>\n      <td>BLAME IT ON BABY</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/DaBaby_-_The_Know_Show.png/220px-DaBaby_-_The_Know_Show.png" width="60" ></td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Watermelon Sugar</td>\n      <td>Harry Styles</td>\n      <td>Fine Line</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Harry_Styles_November_2014.jpg/220px-Harry_Styles_November_2014.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>death bed</td>\n      <td>Powfu</td>\n      <td>death bed</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Falling</td>\n      <td>Trevor Daniel</td>\n      <td>Nicotine</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Someone You Loved</td>\n      <td>Lewis Capaldi</td>\n      <td>Divinely Uninspired To A Hellish Extent</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Lewis_Capaldi.jpg/220px-Lewis_Capaldi.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Tusa</td>\n      <td>KAROL G</td>\n      <td>Tusa</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Karol_G_Telemedell%C3%ADn.jpg/220px-Karol_G_Telemedell%C3%ADn.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>ROXANNE</td>\n      <td>Arizona Zervas</td>\n      <td>ROXANNE</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/3/31/ArizonaZervasLogo.jpg/220px-ArizonaZervasLogo.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>Circles</td>\n      <td>Post Malone</td>\n      <td>Hollywood\'s Bleeding</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/1/12/Post_Malone_at_the_2019_American_Music_Awards.png/220px-Post_Malone_at_the_2019_American_Music_Awards.png" width="60" ></td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Blueberry Faygo</td>\n      <td>Lil Mosey</td>\n      <td>Certified Hitmaker</td>\n      <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/2/25/Lil_Mosey_%2841879461061%29_%28retouched%29.jpg/220px-Lil_Mosey_%2841879461061%29_%28retouched%29.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Intentions</td>\n      <td>Justin Bieber</td>\n      <td>Ch ...

# %%
from IPython.core.display import HTML
HTML(df.to_html(escape=False,formatters=dict(image=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>track_name</th>
#       <th>artist</th>
#       <th>album</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>
>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Supalonely</td>
#       <td>BENEE</td>
#       <td>Hey u x</td>
#       <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/BENEE_%2850117380403%29_%28cropped%29.jpg/220px-BENEE_%2850117380403%29_%28cropped%29.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>ily</td>
#       <td>Surf Mesa</td>
#       <td>ily</td>
#       <td><img src="http://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Surf_Mesa_Powell_Adderley.png/220px-Surf_Mesa_Powell_

# %% [markdown]
# Some pictures still contain the logo of the singer, so we manually empty those cells, so that such pictures will not appear on the final data set.

# %%
df.iloc[11,3] = np.nan
df.iloc[14,3] = np.nan
df.iloc[19,3] = np.nan
df.iloc[30,3] = np.nan
df.iloc[32,3] = np.nan
df.iloc[41,3] = np.nan

# %%
df
# Out:
#                  track_name           artist  \
# 0           Blinding Lights       The Weeknd
# 1              Dance Monkey      Tones And I
# 2                   The Box      Roddy Ricch
# 3                     Roses        SAINt JHN
# 4           Don't Start Now         Dua Lipa
# 5                  ROCKSTAR           DaBaby
# 6          Watermelon Sugar     Harry Styles
# 7                 death bed            Powfu
# 8                   Falling    Trevor Daniel
# 9         Someone You Loved    Lewis Capaldi
# 10                     Tusa          KAROL G
# 11                  ROXANNE   Arizona Zervas
# 12                  Circles      Post Malone
# 13          Blueberry Faygo        Lil Mosey
# 14               Intentions    Justin Bieber
# 15             Toosie Slide            Drake
# 16            Before You Go    Lewis Capaldi
# 17                   Say So         Doja Cat
# 18                 Memories         Maroon 5
# 19             Life Is Good           Future
# 20              Savage Love        Jawsh 685
# 21                Adore You     Harry Styles
# 22              Breaking Me            Topic
# 23                     Mood         24kGoldn
# 24      everything i wanted    Billie Eilish
# 25                 Señorita     Shawn Mendes
# 26                  bad guy    Billie Eilish
# 27                      WAP          Cardi B
# 28              Sunday Best         Surfaces
# 29                 Godzilla           Eminem
# 30                    Yummy    Justin Bieber
# 31           Break My Heart         Dua Lipa
# 32                 Dynamite              BTS
# 33               Supalonely            BENEE
# 34                      ily        Surf Mesa
# 35               Rain On Me        Lady Gaga
# 36      HIGHEST IN THE ROOM     Travis Scott
# 37                Sunflower      Post Malone
# 38                    Hawái           Maluma
# 39                  Ride It           Regard
# 40               goosebumps     Travis Scott
# 41                    RITMO  Black Eyed Peas
# 42               THE SCOTTS       THE SCOTTS
# 43                  Safaera        Bad Bunny
# 44                   lovely    Billie Eilish
# 45             Lucid Dreams       Juice WRLD
# 46             Stuck with U    Ariana Grande
# 47  If the World Was Ending          JP Saxe
# 48                 Physical         Dua Lipa
# 49               SICKO MODE     Travis Scott
#
#                                        album  \
# 0                                After Hours
# 1                               Dance Monkey
# 2      Please Excuse Me For Being Antisocial
# 3                                      Roses
# 4                           Future Nostalgia
# 5                           BLAME IT ON BABY
# 6                                  Fine Line
# 7                                  death bed
# 8                                   Nicotine
# 9    Divinely Uninspired To A Hellish Extent
# 10                                      Tusa
# 11                                   ROXANNE
# 12                      Hollywood's Bleeding
# 13                        Certified Hitmaker
# 14                                   Changes
# 15                      Dark Lane Demo Tapes
# 16   Divinely Uninspired To A Hellish Extent
# 17                                  Hot Pink
# 18                                  Memories
# 19                             High Off Life
# 20                               Savage Love
# 21                                 Fine Line
# 22                               Breaking Me
# 23                                      Mood
# 24                       everything i wanted
# 25                              Shawn Mendes
# 26  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 27                                       WAP
# 28                        Where the Light Is
# 29                   Music To Be Murdered By
# 30                                   Changes
# 31                          Future Nostalgia
# 32                                  Dynamite
# 33                                   Hey u x
# 34                                       ily
# 35                                Chromatica
# 36                       HIGHEST IN THE ROOM
# 37                      Hollywood's Bleeding
# 38                              PAPI JUANCHO
# 39                                   Ride It
# 40           Birds In The Trap Sing McKnight
# 41                               Translation
# 42                                THE SCOTTS
# 43                                  YHLQMDLG
# 44                                    lovely
# 45                   Goodbye & Good Riddance
# 46                              Stuck with U
# 47                   If the World Was Ending
# 48                          Future Nostalgia
# 49                                ASTROWORLD
#
#                                                 image
# 0   http://upload.wikimedia.org/wikipedia/commons/...
# 1   http://upload.wikimedia.org/wikipedia/commons/...
# 2   http://upload.wikimedia.org/wikipedia/commons/...
# 3   http://upload.wikimedia.org/wikipedia/commons/...
# 4                                                 NaN
# 5   http://upload.wikimedia.org/wikipedia/commons/...
# 6   http://upload.wikimedia.org/wikipedia/commons/...
# 7                                                 NaN
# 8                                                 NaN
# 9   http://upload.wikimedia.org/wikipedia/commons/...
# 10  http://upload.wikimedia.org/wikipedia/commons/...
# 11                                                NaN
# 12  http://upload.wikimedia.org/wikipedia/commons/...
# 13  http://upload.wikimedia.org/wikipedia/commons/...
# 14                                                NaN
# 15  http://upload.wikimedia.org/wikipedia/commons/...
# 16  http://upload.wikimedia.org/wikipedia/commons/...
# 17                                                NaN
# 18  http://upload.wikimedia.org/wikipedia/commons/...
# 19                                                NaN
# 20                                                NaN
# 21  http://upload.wikimedia.org/wikipedia/commons/...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  http://upload.wikimedia.org/wikipedia/commons/...
# 34  http://upload.wikimedia.org/wikipedia/commons/...
# 35  http://upload.wikimedia.org/wikipedia/commons/...
# 36  http://upload.wikimedia.org/wikipedia/commons/...
# 37  http://upload.wikimedia.org/wikipedia/commons/...
# 38  http://upload.wikimedia.org/wikipedia/commons/...
# 39                                                NaN
# 40  http://upload.wikimedia.org/wikipedia/commons/...
# 41                                                NaN
# 42                                                NaN
# 43  http://upload.wikimedia.org/wikipedia/commons/...
# 44                                                NaN
# 45  http://upload.wikimedia.org/wikipedia/commons/...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  http://upload.wikimedia.org/wikipedia/commons/...

# %% [markdown]
# Saving the dataframe to a final csv to be used to create the quizz

# %%
df.to_csv('final_2020.csv', index = False)
